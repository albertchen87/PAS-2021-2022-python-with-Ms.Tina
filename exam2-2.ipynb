# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn import datasets

# Load the data
iris = datasets.load_iris()
X = iris.data[:, :2] 
Y = iris.target

# Create the model
logreg = LogisticRegression(C=1e3)
logreg.fit(X, Y)

# Plot the decision boundary
x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5
a = 0.01

#Prediction stuff
x1, y1 = np.meshgrid(np.arange(x_min, x_max, a), np.arange(y_min, y_max, a))
Z = logreg.predict(np.c_[x1.ravel(), y1.ravel()])
Z = Z.reshape(x1.shape)

#Plotting stuff
plt.pcolormesh(x1, y1, Z, cmap=plt.cm.Paired)
plt.scatter(X[:, 0], X[:, 1], c=Y, edgecolors="k", cmap=plt.cm.Paired)
plt.show()
# Out:
# C:\Users\bigsu\AppData\Local\Temp/ipykernel_20792/2714051785.py:26: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(x1, y1, Z, cmap=plt.cm.Paired)
