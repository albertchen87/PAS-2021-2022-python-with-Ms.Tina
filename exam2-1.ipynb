# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import linear_model

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
print(df['bedrooms'].max())
# Out:
# 33

# %%
print((df['sqft_living'] + df['sqft_lot'] + df['sqft_above'] + df['sqft_above'] + df['sqft_basement'] + df['sqft_living15'] + df['sqft_lot15']).max())
# Out:
# 2083400

# %%
print((df['sqft_living'] + df['sqft_lot'] + df['sqft_above'] + df['sqft_above'] + df['sqft_basement'] + df['sqft_living15'] + df['sqft_lot15']).min())
# Out:
# 4561

# %%
print(df['bedrooms'].mode())
# Out:
# 0    3
# dtype: int64

# %%
_,ax=pyplot.subplots(figsize=(30,20))
colormap=sns.diverging_palette(250,20,as_cmap=True)
sns.heatmap(df.corr(),annot=True,cmap=colormap)
# Out:
# <AxesSubplot:>

# %%
train_data,test_data=train_test_split(df,train_size=0.9,random_state=3)
reg=linear_model.LinearRegression()
x_train=np.array(train_data['sqft_living']).reshape(-1,1)
y_train=np.array(train_data['price']).reshape(-1,1)
reg.fit(x_train,y_train)

x_test=np.array(test_data['sqft_living']).reshape(-1,1)
y_test=np.array(test_data['price']).reshape(-1,1)
pred=reg.predict(x_test)
mean_squared_error=metrics.mean_squared_error(y_test,pred)

_, ax = pyplot.subplots(figsize= (30, 20))
pyplot.scatter(x_test, y_test, color= 'blue')
pyplot.plot(x_test, reg.predict(x_test), color='red')
pyplot.legend()
pyplot.gca().spines['right'].set_visible(False)
pyplot.gca().spines['right'].set_visible(False)
# Out:
# No handles with labels found to put in legend.
